# %% [markdown]
# <div align="center">
#     <img src="https://www.sharif.ir/documents/20124/0/logo-fa-IR.png/4d9b72bc-494b-ed5a-d3bb-e7dfd319aec8?t=1609608338755" alt="Logo" width="200">
#     <p><b>HW1 @ Deep Learning Course, Dr. Soleymani</b></p>
#     <p><b>ِDesinged by Amirmahdi Meighani</b></p>
# </div>
#
# ---

# %% [markdown]
# *Full Name:* Hossein Rezazadeh

# %% [markdown]
# # Overview: Building a Neural Network Framework with NumPy
#
# In this assignment, you will build a simple **Multi-Layer Perceptron (MLP) framework** using only NumPy. By implementing each component step by step, you will gain a fundamental understanding of **forward and backward propagation**, **loss functions**, and **optimization techniques**.
#
# Each part of the assignment builds on the previous one.
#
# ### Goal
# To build a modular **Multi-Layer Perceptron (MLP)** framework using NumPy from scratch.
#
# ### Structure of the Assignment
#
# Each section below builds towards the final goal of training an MLP. The first steps focus on implementing fundamental components, while later steps involve integrating them into a complete training pipeline.
#
# #### **Step 1: Implementing Core Functions (70 points)**
# - **Forward & Backward Passes (10 points):** Implement `affine_forward` and `affine_backward` to compute layer outputs and gradients.
# - **Activation Functions (20 points):** Implement ReLU and Sigmoid functions (`relu_forward/backward`, `sigmoid_forward/backward`).
# - **Loss Calculation (15 points):** Implement `mse_loss` to compute Mean Squared Error and its gradient.
# - **Building a Multi-Layer Network (15 points):** Define a `FullyConnectedNet` class that integrates all layers and computes forward and backward passes.
# - **Optimization (10 points):** Implement `sgd_momentum` to update parameters.
#
# #### **Step 2: Training & Evaluation (30 points)**
# - **Training (25 points):** Train the `FullyConnectedNet` using a `Solver` class.
# - **Evaluation (5 points):** Assess the model on validation/test data.
# **__Your score on this section is based on the result of your model and defines how well the previous sections are implemented.__*

# %%
pip install future pandas  torchvision
# Out:
# Requirement already satisfied: future in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.0.0)
# Requirement already satisfied: pandas in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.2.3)
# Requirement already satisfied: torchvision in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.26.0+cu128)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\hossein\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: torch==2.11.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torchvision) (2.11.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (4.13.0)
# Requirement already satisfied: setuptools<82 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (78.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.11.0->torchvision) (2025.9.0)
# Requirement already satisfied: six>=1.5 in C:\Users\hossein\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch==2.11.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\hossein\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch==2.11.0->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from utils.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from utils.data import get_california_housing_data, get_california_housing_normalized__data
from builtins import range
import numpy as np
import matplotlib.pyplot as plt
from utils.solver import *
import pandas as pd
from sklearn.datasets import fetch_california_housing



# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.cmap'] = 'gray'

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def print_mean_std(x,axis=0):
    print(f"  means: {x.mean(axis=axis)}")
    print(f"  stds:  {x.std(axis=axis)}\n")

# %% [markdown]
# **Intresting** 🔴

# %% [markdown]
# # Fully-Connected Neural Nets
# In this exercise we will implement fully-connected networks using a modular approach. For each layer we will implement a generic `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
#
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build different models with architectures.
#
# ### In Simple Words
# I have a `dout` which is the derivative of Loss with respect to the `output` of this layer. With the help of `cache`, I calculate the local derivative of the layer and with the chain rule, I get dx or gradient with respect to the input.

# %% [markdown]
# # Affine layer: forward (5 Points)
# Implement the `affine_forward` function.

# %%
def affine_forward(x, w, b):
    """
    Computes the forward pass for an affine (fully-connected) layer.

    The input x has shape (N, d_1, ..., d_k) and contains a minibatch of N
    examples, where each example x[i] has shape (d_1, ..., d_k). We will
    reshape each input into a vector of dimension D = d_1 * ... * d_k, and
    then transform it to an output vector of dimension M.

    Inputs:
    - x: A numpy array containing input data, of shape (N, d_1, ..., d_k)
    - w: A numpy array of weights, of shape (D, M)
    - b: A numpy array of biases, of shape (M,)

    Returns a tuple of:
    - out: output, of shape (N, M)
    - cache: (x, w, b)
    """
    ###########################################################################
    # TODO: Implement the affine forward pass. Store the result in out. You   #
    # will need to reshape the input into rows.                               #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    x_reshaped = x.reshape(x.shape[0] , np.prod(x.shape[1:]))# Reshape to (N, D)
    #print("Shape after reshaping input:", x_reshaped.shape)
    out = np.matmul(x_reshaped , w.reshape(np.prod(x.shape[1:]) , b.shape[0])) + b # compute out
    #print("Shape after affine transformation:", out.shape)
    cache =(x , w , b) # Values we need to compute gradients

    return out, cache

# %% [markdown]
# You can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])


# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Affine layer: backward (5 Points)
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.
#
#
# Given an affine transformation in a neural network:
#
# $
# Z = XW + b
# $
#
# where:
# - $ X $ is the input matrix of shape $ (N, D) $
# - $ W $ is the weight matrix of shape $ (D, M) $
# - $ b $ is the bias vector of shape $ (1, M) $
# - $ Z $ is the output before activation of shape $ (N, M) $
#
# ### Backward Pass Gradients:
#
# 1. **Gradient w.r.t. input $ X $:**
#  $
#    dX = dZ W^T
# $
#    (Shape: $ (N, D) $)
#
# 2. **Gradient w.r.t. weights $ W $:**
#    $
#    dW = X^T dZ
#    $
#    (Shape: $ (D, M) $)
#
# 3. **Gradient w.r.t. bias $ b $:**
#    $
#    db = \sum_{i=1}^{N} dZ_i
#    $
#    (Shape: $ (1, M) $)

# %%
def affine_backward(dout, cache):
    """
    Computes the backward pass for an affine layer.

    Inputs:
    - dout: Upstream derivative, of shape (N, M)
    - cache: Tuple of:
      - x: Input data, of shape (N, d_1, ... d_k)
      - w: Weights, of shape (D, M)
      - b: Biases, of shape (M,)

    Returns a tuple of:
    - dx: Gradient with respect to x, of shape (N, d1, ..., d_k)
    - dw: Gradient with respect to w, of shape (D, M)
    - db: Gradient with respect to b, of shape (M,)
    """
    ###########################################################################
    # TODO: Implement the affine backward pass.                               #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    x, w, b = cache
    
    x_reshaped = x.reshape(x.shape[0], -1)
    dx_reshaped = dout.dot(w.T)
    
    dx = dx_reshaped.reshape(x.shape)
    dw = x_reshaped.T.dot(dout)
    db = dout.sum(axis=0)

    return dx,dw,db

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # ReLU activation: forward (5 Points)
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using numeric gradient checking.

# %%
def relu_forward(x):
    """
    Computes the forward pass for a layer of rectified linear units (ReLUs).

    Input:
    - x: Inputs, of any shape

    Returns a tuple of:
    - out: Output, of the same shape as x
    - cache: x
    """
    ###########################################################################
    # TODO: Implement the ReLU forward pass.                                  #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    out = np.maximum(0 , x)# compute ReLU(x)
    cache = x

    return out, cache

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU activation: backward (5 Points)
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function.
#
#
# ReLU Activation Backward Pass:
#
# Given the ReLU activation function:
#
# $ A = \max(0, Z) $
#
# where $ A $ is the output after activation, and $ Z $ is the pre-activation input.
#
# 1. **Gradient w.r.t. pre-activation input $ Z $:**
#    $
#    dZ = dA \cdot \mathbb{1}(Z > 0)
#    $
#
#    (Element-wise multiplication where $ \mathbb{1}(Z > 0) $ is an indicator function that is $1$ when $ Z > 0 $ and 0 otherwise.)

# %%
def relu_backward(dout, cache):
    """
    Computes the backward pass for a layer of rectified linear units (ReLUs).

    Input:
    - dout: Upstream derivatives, of any shape
    - cache: Input x, of same shape as dout

    Returns:
    - dx: Gradient with respect to x
    """
    ###########################################################################
    # TODO: Implement the ReLU backward pass.                                 #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    dx = dout * (cache > 0)     # masking cache into True , False: [True, True , False,...]

    return dx

# %% [markdown]
# You can test your implementation using numeric gradient checking:

# %%
# Test the relu_backward function
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# # Sigmoid activation: forward (5 Points)
# Implement the forward pass for the Sigmoid activation function in the `sigmoid_forward` function and test your implementation using numeric gradient checking.

# %% [markdown]
# $
# A = \sigma(Z) = \frac{1}{1 + e^{-Z}}
# $

# %%
def sigmoid_forward(x):
    """
    Computes the forward pass for a layer of Sigmoid.

    Input:
    - x: Inputs, of any shape

    Returns a tuple of:
    - out: Output, of the same shape as x
    - cache: x
    """
    ###########################################################################
    # TODO: Implement the Sigmoid forward pass.                               #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    out = (1/(1+np.exp(-x)))# compute Sigmoid(x)
    cache = x

    return out, cache

# %%
# Test the sigmoid_forward function

x = np.linspace(-6, 6, num=12).reshape(3, 4)

out, _ = sigmoid_forward(x)
correct_out = np.array([[0.00247262, 0.00732514, 0.0214955 , 0.06138311],
                        [0.16296047, 0.36691963, 0.63308037, 0.83703953],
                        [0.93861689, 0.9785045 , 0.99267486, 0.99752738]])

# Compare your output with ours. The error should be on the order of e-7
print('Testing sigmoid_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing sigmoid_forward function:
# difference:  6.383174040859927e-07

# %% [markdown]
# # Sigmoid activation: backward (5 Points)
# Now implement the backward pass for the Sigmoid activation function in the `sigmoid_backward` function.
#
# Given the Sigmoid activation function:
#
# $
# A = \sigma(Z) = \frac{1}{1 + e^{-Z}}
# $
#
# where $ A $ is the output after activation, and $ Z $ is the pre-activation input.
#
# The derivative of the Sigmoid function is:
#
# $
# \frac{dA}{dZ} = \sigma(Z) (1 - \sigma(Z))
# $
#
# The backward pass computes the gradient:
#
# 1. **Gradient w.r.t. pre-activation input $ Z $:**
#    $
#    dZ = dA \cdot \sigma(Z) (1 - \sigma(Z))
#    $
#
#    (Element-wise multiplication using the derivative of Sigmoid.)

# %%
def sigmoid_backward(dout, cache):
    """
    Computes the backward pass for a layer of Sigmoid.

    Input:
    - dout: Upstream derivatives, of any shape
    - cache: Input x, of same shape as dout

    Returns:
    - dx: Gradient with respect to x
    """
    ###########################################################################
    # TODO: Implement the Sigmoid backward pass.                              #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    dx = (dout) * (sigmoid_forward(cache)[0])*(1-(sigmoid_forward(cache)[0]))# Derivative of loss with respect to x
    return dx

# %% [markdown]
# You can test your implementation using numeric gradient checking:

# %%
# Test the sigmoid_backward function
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: sigmoid_forward(x)[0], x, dout)

_, cache = sigmoid_forward(x)
dx = sigmoid_backward(dout, cache)

# The error should be on the order of e-11
print('Testing sigmoid_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing sigmoid_backward function:
# dx error:  3.446520386706568e-11

# %% [markdown]
# # Loss layer: MSE (15 Points)
# Now implement the loss and gradient for mean squared error in the `mse_loss` function.

# %% [markdown]
# **Intresting** 🟡

# %%
def mse_loss(x, y):
    """
    Computes the loss and gradient for MSE loss.

    Inputs:
    - x: Input data, of shape (N,) where x[i] is the predicted vector for
        the ith input.
    - y: Vector of target values, of shape (N,) where y[i] is the target value
        for the ith input.

    Returns a tuple of:
    - loss: Scalar giving the loss
    - dx: Gradient of the loss with respect to x
    """
    ###########################################################################
    # TODO: Implement the mse_loss function.                                  #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    x_orig_shape = x.shape
    x = np.squeeze(x)


    MSE = np.mean(np.power((x-y) , 2))  # compute MSE(x,y) Attention; we want a vector
    N = x.shape[0]
    dx = (2/N) * (x-y)# Derivative of loss with respect to x


    dx = dx.reshape(x_orig_shape)# match the shapes

    assert dx.shape == x_orig_shape, "Shape of gradient dx does not match the original shape of input data x"

    return MSE, dx

# %% [markdown]
# You can make sure that the implementations are correct by running the following:

# %%
np.random.seed(231)
num_inputs = 50
x = np.random.randn(num_inputs)
y = np.random.randn(num_inputs)

dx_num = eval_numerical_gradient(lambda x: mse_loss(x, y)[0], x, verbose=False)
loss, dx = mse_loss(x, y)

# Test mse_loss function. Loss should be close to 1.9 and dx error should be around e-9
print('\nTesting mse_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing mse_loss:
# loss:  1.8672282748726519
# dx error:  2.8607953262121067e-09

# %% [markdown]
# # Multi-Layer Fully Connected Network (15 Points)
# In this part, you will implement a fully connected network with an arbitrary number of hidden layers.

# %%
class FullyConnectedNet(object):
    """Class for a multi-layer fully connected neural network.

    Network contains an arbitrary number of hidden layers, ReLU nonlinearities,
    and a softmax loss function for a classification problem or the MSE loss function for
    a regression problem. The architecture will be

    {affine - relu} x (L - 1) - affine - softmax/mse

    where the {...} block is repeated L - 1 times.

    Learnable parameters are stored in the self.params dictionary and will be learned
    using the Solver class.
    """

    def __init__(
        self,
        hidden_dims,
        input_dim=784,
        output_dim=10,
        reg=0.0,
        weight_scale=1e-2,
        dtype=np.float32,
    ):
        """Initialize a new FullyConnectedNet.

        Inputs:

        - hidden_dims: A list of integers giving the size of each hidden layer.
        - input_dim: An integer giving the size of the input.
        - output_dim: An integer giving the number of classes to classify. It
            is 1 for a regression problem.
        - reg: Scalar giving L2 regularization strength.
        - weight_scale: Scalar giving the standard deviation for random
            initialization of the weights.
        - dtype: A numpy datatype object; all computations will be performed using
            this datatype. float32 is faster but less accurate, so you should use
            float64 for numeric gradient checking.
        """
        self.category = 'regression'
        self.reg = reg
        self.num_layers = 1 + len(hidden_dims)
        self.dtype = dtype
        self.params = {}

        ############################################################################
        # TODO: Initialize the parameters of the network, storing all values in    #
        # the self.params dictionary. Store weights and biases for the first layer #
        # in W1 and b1; for the second layer use W2 and b2, etc. Weights should be #
        # initialized from a normal distribution centered at 0 with standard       #
        # deviation equal to weight_scale. Biases should be initialized to zero.   #
        #                                                                          #
        ############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        layer_dims = [input_dim] + hidden_dims + [output_dim]
        for i in range(1, self.num_layers + 1):
            self.params[f'W{i}'] = np.random.randn(layer_dims[i-1], layer_dims[i]) * weight_scale
            self.params[f'b{i}'] = np.zeros(layer_dims[i])
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        ############################################################################
        #                             END OF YOUR CODE                             #
        ############################################################################


        # Cast all parameters to the correct datatype.
        for k, v in self.params.items():
            self.params[k] = v.astype(dtype)

    def loss(self, X, y=None):
        """Compute loss and gradient for the fully connected net.

        Inputs:
        - X: Array of input data of shape (N, d_1, ..., d_k)
        - y: Array of labels / target values, of shape (N,). y[i] gives the
            label / target value for X[i].
        - show_distributions: Boolean that if enabled and y in none, show output
        of each layer to see effects of diffrent approaches

        Returns:
        If y is None, then run a test-time forward pass of the model and return
        scores for a classification problem or the predicted_values for
        a regression problem:
        - out: Array of shape (N, C) / (N, ) giving classification scores / predicted values, where
        scores[i, c] is the classification score for X[i] and class c / predicted_values[i]
        is the predicted value for X[i].


        If y is not None, then run a training-time forward and backward pass and
        return a tuple of:
        - loss: Scalar value giving the loss
        - grads: Dictionary with the same keys as self.params, mapping parameter
            names to gradients of the loss with respect to those parameters.
        """
        X = X.astype(self.dtype)
        mode = "test" if y is None else "train"

        ############################################################################
        # TODO: Implement the forward pass for the fully connected net, computing  #
        # the class scores / target values for X and storing them in the out       #
        #  variable.                                                               #
        #                                                                          #
        ############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        out = X.reshape(X.shape[0], -1)
        self.layer_cache = {}
        layer_outputs = []  # saving layer outputs for visualization
        layer_outputs.append(out)

        # forward pass
        for i in range(1, self.num_layers):
            out, cache_affine = affine_forward(out, self.params[f'W{i}'], self.params[f'b{i}'])
            out, cache_relu = relu_forward(out)
            self.layer_cache[f'layer{i}'] = (cache_affine, cache_relu)  # Saving for Backprop
            layer_outputs.append(out)

        out, cache_affine = affine_forward(out, self.params[f'W{self.num_layers}'], 
                                           self.params[f'b{self.num_layers}'])
        self.layer_cache[f'layer{self.num_layers}'] = (cache_affine,)   # for creating one unit tuple
        layer_outputs.append(out)
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        ############################################################################
        #                             END OF YOUR CODE                             #
        ############################################################################

        # If test mode return early.
        if mode == "test":
            return out

        loss, grads = 0.0, {}
        ############################################################################
        # TODO: Implement the backward pass for the fully connected net. Store the #
        # loss in the loss variable and gradients in the grads dictionary. Compute #
        # data loss using mse, and make sure that grads[k] holds the               #
        # gradients for self.params[k]. Don't forget to add L2 regularization!     #
        #                                                                          #
        #                                                                          #
        # NOTE: To ensure that your implementation matches ours and you pass the   #
        # automated tests, make sure that your L2 regularization includes a factor #
        # of 0.5 to simplify the expression for the gradient.                      #
        ############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        N = X.shape[0]
        
        # compute loss
        # Regression
        if self.category == 'regression' or out.shape[1] == 1:
            y_flat = y.reshape(-1, 1) if y.ndim == 1 else y # to be ensure of the mutual dimension
            diff = out - y_flat
            loss = 0.5 * np.mean(diff**2)   # MSE loss
            dyhat = diff / N
        # Classification
        else:
            exp_scores = np.exp(out - np.max(out, axis=1, keepdims=True))
            probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
            loss = -np.mean(np.log(probs[np.arange(N), y] + 1e-8))
            dyhat = probs.copy()
            dyhat[np.arange(N), y] -= 1
            dyhat /= N

        # L2 Regularization (loss)
        for i in range(1, self.num_layers + 1):
            loss += 0.5 * self.reg * np.sum(self.params[f'W{i}']**2)

        # Backpropagation affine
        dout = dyhat
        for i in range(self.num_layers, 0, -1):
            if i == self.num_layers:
                cache_affine = self.layer_cache[f'layer{i}'][0]
                dout, grads[f'W{i}'], grads[f'b{i}'] = affine_backward(dout, cache_affine)
            else:
                cache_affine, cache_relu = self.layer_cache[f'layer{i}']
                dout = relu_backward(dout, cache_relu)
                dout, grads[f'W{i}'], grads[f'b{i}'] = affine_backward(dout, cache_affine)

        # Regularization (gradients)
            grads[f'W{i}'] += self.reg * self.params[f'W{i}']
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        ############################################################################
        #                             END OF YOUR CODE                             #
        ############################################################################

        return loss, grads

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2 = 2, 15, 20, 30
X = np.random.randn(N, D)
y = np.random.randint(123, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        output_dim=1,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2733.432853125636
# W1 relative error: 5.635683954807205e-05
# W2 relative error: 1.613210683498996e-05
# W3 relative error: 6.898987504530194e-07
# b1 relative error: 1.5616081970079422e-06
# b2 relative error: 4.3057176756698825e-08
# b3 relative error: 1.6746974192121475e-10
# Running check with reg =  3.14
# Initial loss:  2736.9901165009996
# W1 relative error: 8.955626408537923e-06
# W2 relative error: 0.0002767463523247671
# W3 relative error: 9.137044716569541e-07
# b1 relative error: 2.626926800500172e-07
# b2 relative error: 1.2120991887982816e-07
# b3 relative error: 1.7983206598641928e-10

# %% [markdown]
# ## SGD+Momentum (10 Points)
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent.
#
# Implement the SGD+momentum update rule in the function `sgd_momentum`.
#
# ### Question:
# How does the behavior of the optimization process, specifically the trajectory through the loss landscape, differ when using Stochastic Gradient Descent (SGD) with momentum compared to using vanilla SGD?

# %%
def sgd_momentum(w, dw, config=None):
    """
    Performs stochastic gradient descent with momentum.
    Inputs:
    - w: A numpy array giving the current weights.
    - dw: A numpy array of the same shape as w giving the gradient of the
    loss with respect to w.
    - config: A dictionary containing hyperparameter values such as learning
    rate, momentum.

    Returns:
      - next_w: The next point after the update.
      - config: The config dictionary to be passed to the next iteration of the
        update rule.

    config format:
    - learning_rate: Scalar learning rate.
    - momentum: Scalar between 0 and 1 giving the momentum value.
      Setting momentum = 0 reduces sgd_momentum to stochastic gradient descent.
    - velocity: A numpy array of the same shape as w and dw used to store a
      moving average of the gradients.
    """
    if config is None:
        config = {}
    config.setdefault("learning_rate", 1e-2)
    config.setdefault("momentum", 0.9)
    v = config.get("velocity", np.zeros_like(w))

    next_w = None
    ###########################################################################
    # TODO: Implement the momentum update formula. Store the updated value in #
    # the next_w variable. You should also use and update the velocity v.     #
    ###########################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    v = config["momentum"] * v - config["learning_rate"]* dw  # compute the velocity
    next_w = w + v # update weights

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################
    config["velocity"] = v

    return next_w, config

# %% [markdown]
# Run the following to check your implementation. You should see errors less than e-8.

# %%
N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# # Real World Application
# Now that we have implemented the core functions and built a multilayer network, and tested it on random data to ensure it functions correctly, It is time to train the model on a real dataset. For this, we will use the California Housing dataset, which contains information about housing prices in different districts of California. The dataset includes features such as median income, house age, and population, making it a useful benchmark for regression tasks. Our goal is to train the network to predict house prices based on these features.

# %% [markdown]
# # California housing dataset
# This is a dataset obtained from the [StatLib repository](https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html). The data pertains to the houses found in a given California district and some summary stats about them based on the 1990 census data.

# %%
california_housing = fetch_california_housing(as_frame=True)
california_housing.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
X_train, y_train, X_val, y_val, X_test, y_test = get_california_housing_data()
print('Train data shape: ', X_train.shape)
print('Train target values shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation target values shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test target values shape: ', y_test.shape)
# Out:
# Train data shape:  (15640, 8)
# Train target values shape:  (15640,)
# Validation data shape:  (2500, 8)
# Validation target values shape:  (2500,)
# Test data shape:  (2500, 8)
# Test target values shape:  (2500,)

# %%
X_train, X_val, X_test = get_california_housing_normalized__data(X_train, X_val, X_test)

# %% [markdown]
# # Training (25)
# Train the best fully connected model that you can on california housing, storing your best model in the `california_housing_best_model` variable.
# Your final score depends on the accuracy(since your model is performing regression accuracy is equal to loss) of your best model reported in this notebook.

# %%
california_housing_best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on california housing.   #
# You might find batch normalization useful. Store your best model in          #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

data = {
    'X_train': X_train,
    'y_train': y_train,
    'X_val': X_val,
    'y_val': y_val,
    'X_test': X_test,
    'y_test': y_test
    }

best_overall_val_acc = float('inf') # Initializing the validation
best_overall_model = None
best_overall_solver = None
best_hyperparams = {}

hidden_dims_list = [
    [24, 48],     
    [24, 96, 32], 
    [32, 128, 64, 32]  
]

learning_rates = [1e-3, 5e-4]

for hidden_dims in hidden_dims_list:
    for lr in learning_rates:
        print(f"**** Training Structuire | Hidden Dims: {hidden_dims} | LR: {lr} ---")
        
        model = FullyConnectedNet(
            hidden_dims=hidden_dims,
            input_dim=X_train.shape[1],  
            output_dim=1,  
            reg=0.01, 
            weight_scale=5e-2,  
            dtype=np.float64
        )

        solver = Solver(model, data,
                        update_rule=sgd_momentum,
                        optim_config={'learning_rate': lr, 'momentum': 0.95},
                        lr_decay=0.995,  
                        num_epochs=15,  
                        batch_size=128,  
                        )  
        
        solver.best_val_acc = float('inf')
        
        solver.train()
        
        current_val_acc = solver.best_val_acc 
        print(f"Validation RMS Error = {current_val_acc:.4f}\n")

        if current_val_acc < best_overall_val_acc:
            best_overall_val_acc = current_val_acc
            best_overall_model = model
            best_overall_solver = solver
            best_hyperparams = {'hidden_dims': hidden_dims, 'lr': lr}

print(f"Optimal Hyperparameters: {best_hyperparams}")
print(f"Lowest Validation RMS Error: {best_overall_val_acc:.4f}")

california_housing_best_model = best_overall_model
california_housing_solver = best_overall_solver
# Out:
# **** Training Structuire | Hidden Dims: [24, 48] | LR: 0.001 ---
# (Iteration 1 / 1830) loss: 2.122179
# (Epoch 0 / 15) train RMS error: 1.638508; val RMS error: 2.102409
# (Iteration 11 / 1830) loss: 2.148084
# (Iteration 21 / 1830) loss: 1.770645
# (Iteration 31 / 1830) loss: 1.679480
# (Iteration 41 / 1830) loss: 1.261407
# (Iteration 51 / 1830) loss: 0.972321
# (Iteration 61 / 1830) loss: 0.547536
# (Iteration 71 / 1830) loss: 0.777826
# (Iteration 81 / 1830) loss: 0.804336
# (Iteration 91 / 1830) loss: 0.540590
# (Iteration 101 / 1830) loss: 0.615395
# (Iteration 111 / 1830) loss: 0.639088
# (Iteration 121 / 1830) loss: 0.496364
# (Epoch 1 / 15) train RMS error: 0.825205; val RMS error: 0.994553
# (Iteration 131 / 1830) loss: 0.668867
# (Iteration 141 / 1830) loss: 0.737094
# (Iteration 151 / 1830) loss: 0.567770
# (Iteration 161 / 1830) loss: 0.569043
# (Iteration 171 / 1830) loss: 0.651015
# (Iteration 181 / 1830) loss: 0.552937
# (Iteration 191 / 1830) loss: 0.564895
# (Iteration 201 / 1830) loss: 0.697011
# (Iteration 211 / 1830) loss: 0.587055
# (Iteration 221 / 1830) loss: 0.661327
# (Iteration 231 / 1830) loss: 0.637711
# (Iteration 241 / 1830) loss: 0.479856
# (Epoch 2 / 15) train RMS error: 0.785454; val RMS error: 1.000594
# (Iteration 251 / 1830) loss: 0.846915
# (Iteration 261 / 1830) loss: 0.592226
# (Iteration 271 / 1830) loss: 0.696303
# (Iteration 281 / 1830) loss: 0.619127
# (Iteration 291 / 1830) loss: 0.818354
# (Iteration 301 / 1830) loss: 0.444388
# (Iteration 311 / 1830) loss: 0.639910
# (Iteration 321 / 1830) loss: 0.562011
# (Iteration 331 / 1830) loss: 0.525396
# (Iteration 341 / 1830) loss: 0.533316
# (Iteration 351 / 1830) loss: 0.504642
# (Iteration 361 / 1830) loss: 0.594828
# (Epoch 3 / 15) train RMS error: 0.765588; val RMS error: 0.966910
# (Iteration 371 / 1830) loss: 0.536530
# (Iteration 381 / 1830) loss: 0.583773
# (Iteration 391 / 1830) loss: 0.616509
# (Iteration 401 / 1830) loss: 0.571447
# (Iteration 411 / 1830) loss: 0.499534
# (Iteration 421 / 1830) loss: 0.495757
# (Iteration 431 / 1830) loss: 0.551176
# (Iteration 441 / 1830) loss: 0.541457
# (Iteration 451 / 1830) loss: 0.507696
# (Iteration 461 / 1830) loss: 0.390054
# (Iteration 471 / 1830) loss: 0.289714
# (Iteration 481 / 1830) loss: 0.452925
# (Epoch 4 / 15) train RMS error: 0.658623; val RMS error: 0.844025
# (Iteration 491 / 1830) loss: 0.447464
# (Iteration 501 / 1830) loss: 0.446199
# (Iteration 511 / 1830) loss: 0.415426
# (Iteration 521 / 1830) loss: 0.257851
# (Iteration 531 / 1830) loss: 0.339879
# (Iteration 541 / 1830) loss: 0.429429
# (Iteration 551 / 1830) loss: 0.321465
# (Iteration 561 / 1830) loss: 0.290201
# (Iteration 571 / 1830) loss: 0.286992
# (Iteration 581 / 1830) loss: 0.308776
# (Iteration 591 / 1830) loss: 0.347262
# (Iteration 601 / 1830) loss: 0.320550
# (Epoch 5 / 15) train RMS error: 0.579532; val RMS error: 0.796251
# (Iteration 611 / 1830) loss: 0.439238
# (Iteration 621 / 1830) loss: 0.272444
# (Iteration 631 / 1830) loss: 0.316685
# (Iteration 641 / 1830) loss: 0.315958
# (Iteration 651 / 1830) loss: 0.265023
# (Iteration 661 / 1830) loss: 0.309444
# (Iteration 671 / 1830) loss: 0.304016
# (Iteration 681 / 1830) loss: 0.177014
# (Iteration 691 / 1830) loss: 0.267741
# (Iteration 701 / 1830) loss: 0.443659
# (Iteration 711 / 1830) loss: 0.389101
# (Iteration 721 / 1830) loss: 0.291169
# (Iteration 731 / 1830) loss: 0.426396
# (Epoch 6 / 15) train RMS error: 0.567362; val RMS error: 0.752794
# (Iteration 741 / 1830) loss: 0.302586
# (Iteration 751 / 1830) loss: 0.315236
# (Iteration 761 / 1830) loss: 0.226230
# (Iteration 771 / 1830) loss: 0.378547
# (Iteration 781 / 1830) loss: 0.390456
# (Iteration 791 / 1830) loss: 0.323891
# (Iteration 801 / 1830) loss: 0.236057
# (Iteration 811 / 1830) loss: 0.223224
# (Iteration 821 / 1830) loss: 0.300138
# (Iteration 831 / 1830) loss: 0.244487
# (Iteration 841 / 1830) loss: 0.314001
# (Iteration 851 / 1830) loss: 0.283305
# (Epoch 7 / 15) train RMS error: 0.581415; val RMS error: 0.738919
# (Iteration 861 / 1830) loss: 0.301620
# (Iteration 871 / 1830) loss: 0.241210
# (Iteration 881 / 1830) loss: 0.332393
# (Iteration 891 / 1830) loss: 0.382577
# (Iteration 901 / 1830) loss: 0.221304
# (Iteration 911 / 1830) loss: 0.175915
# (Iteration 921 / 1830) loss: 0.303415
# (Iteration 931 / 1830) loss: 0.259276
# (Iteration 941 / 1830) loss: 0.356111
# (Iteration 951 / 1830) loss: 0.284811
# (Iteration 961 / 1830) loss: 0.357092
# (Iteration 971 / 1830) loss: 0.337350
# (Epoch 8 / 15) train RMS error: 0.536686; val RMS error: 0.707005
# (Iteration 981 / 1830) loss: 0.518418
# (Iteration 991 / 1830) loss: 0.259071
# (Iteration 1001 / 1830) loss: 0.229787
# (Iteration 1011 / 1830) loss: 0.258496
# (Iteration 1021 / 1830) loss: 0.240154
# (Iteration 1031 / 1830) loss: 0.356325
# (Iteration 1041 / 1830) loss: 0.277416
# (Iteration 1051 / 1830) loss: 0.253280
# (Iteration 1061 / 1830) loss: 0.273554
# (Iteration 1071 / 1830) loss: 0.253903
# (Iteration 1081 / 1830) loss: 0.362311
# (Iteration 1091 / 1830) loss: 0.403503
# (Epoch 9 / 15) train RMS error: 0.517839; val RMS error: 0.693772
# (Iteration 1101 / 1830) loss: 0.234936
# (Iteration 1111 / 1830) loss: 0.272424
# (Iteration 1121 / 1830) loss: 0.288677
# (Iteration 1131 / 1830) loss: 0.279913
# (Iteration 1141 / 1830) loss: 0.251093
# (Iteration 1151 / 1830) loss: 0.255715
# (Iteration 1161 / 1830) loss: 0.315524
# (Iteration 1171 / 1830) loss: 0.270145
# (Iteration 1181 / 1830) loss: 0.310388
# (Iteration 1191 / 1830) loss: 0.286749
# (Iteration 1201 / 1830) loss: 0.279089
# (Iteration 1211 / 1830) loss: 0.193683
# (Epoch 10 / 15) train RMS error: 0.537034; val RMS error: 0.680619
# (Iteration 1221 / 1830) loss: 0.201508
# (Iteration 1231 / 1830) loss: 0.247524
# (Iteration 1241 / 1830) loss: 0.273618
# (Iteration 1251 / 1830) loss: 0.268915
# (Iteration 1261 / 1830) loss: 0.334414
# (Iteration 1271 / 1830) loss: 0.293751
# (Iteration 1281 / 1830) loss: 0.230886
# (Iteration 1291 / 1830) loss: 0.309036
# (Iteration 1301 / 1830) loss: 0.255320
# (Iteration 1311 / 1830) loss: 0.215672
# (Iteration 1321 / 1830) loss: 0.281948
# (Iteration 1331 / 1830) loss: 0.199506
# (Iteration 1341 / 1830) loss: 0.255666
# (Epoch 11 / 15) train RMS error: 0.504885; val RMS error: 0.646873
# (Iteration 1351 / 1830) loss: 0.231221
# (Iteration 1361 / 1830) loss: 0.229822
# (Iteration 1371 / 1830) loss: 0.197344
# (Iteration 1381 / 1830) loss: 0.263930
# (Iteration 1391 / 1830) loss: 0.225514
# (Iteration 1401 / 1830) loss: 0.264650
# (Iteration 1411 / 1830) loss: 0.260540
# (Iteration 1421 / 1830) loss: 0.325930
# (Iteration 1431 / 1830) loss: 0.282470
# (Iteration 1441 / 1830) loss: 0.294438
# (Iteration 1451 / 1830) loss: 0.282963
# (Iteration 1461 / 1830) loss: 0.281016
# (Epoch 12 / 15) train RMS error: 0.496960; val RMS error: 0.642747
# (Iteration 1471 / 1830) loss: 0.247128
# (Iteration 1481 / 1830) loss: 0.248256
# (Iteration 1491 / 1830) loss: 0.216109
# (Iteration 1501 / 1830) loss: 0.300291
# (Iteration 1511 / 1830) loss: 0.223405
# (Iteration 1521 / 1830) loss: 0.238786
# (Iteration 1531 / 1830) loss: 0.309287
# (Iteration 1541 / 1830) loss: 0.228761
# (Iteration 1551 / 1830) loss: 0.249869
# (Iteration 1561 / 1830) loss: 0.165749
# (Iteration 1571 / 1830) loss: 0.200556
# (Iteration 1581 / 1830) loss: 0.187771
# (Epoch 13 / 15) train RMS error: 0.526667; val RMS error: 0.635434
# (Iteration 1591 / 1830) loss: 0.267793
# (Iteration 1601 / 1830) loss: 0.296738
# (Iteration 1611 / 1830) loss: 0.284560
# (Iteration 1621 / 1830) loss: 0.240088
# (Iteration 1631 / 1830) loss: 0.268247
# (Iteration 1641 / 1830) loss: 0.222504
# (Iteration 1651 / 1830) loss: 0.210256
# (Iteration 1661 / 1830) loss: 0.244469
# (Iteration 1671 / 1830) loss: 0.186833
# (Iteration 1681 / 1830) loss: 0.204660
# (Iteration 1691 / 1830) loss: 0.180462
# (Iteration 1701 / 1830) loss: 0.237307
# (Epoch 14 / 15) train RMS error: 0.510266; val RMS error: 0.624136
# (Iteration 1711 / 1830) loss: 0.251698
# (Iteration 1721 / 1830) loss: 0.320678
# (Iteration 1731 / 1830) loss: 0.257656
# (Iteration 1741 / 1830) loss: 0.239890
# (Iteration 1751 / 1830) loss: 0.226873
# (Iteration 1761 / 1830) loss: 0.233723
# (Iteration 1771 / 1830) loss: 0.268398
# (Iteration 1781 / 1830) loss: 0.217114
# (Iteration 1791 / 1830) loss: 0.225726
# (Iteration 1801 / 1830) loss: 0.291303
# (Iteration 1811 / 1830) loss: 0.395406
# (Iteration 1821 / 1830) loss: 0.245752
# (Epoch 15 / 15) train RMS error: 0.508977; val RMS error: 0.620848
# Validation RMS Error = 0.6208
#
# **** Training Structuire | Hidden Dims: [24, 48] | LR: 0.0005 ---
# (Iteration 1 / 1830) loss: 2.960800
# (Epoch 0 / 15) train RMS error: 1.654753; val RMS error: 2.105739
# (Iteration 11 / 1830) loss: 3.295998
# (Iteration 21 / 1830) loss: 2.357806
# (Iteration 31 / 1830) loss: 2.004946
# (Iteration 41 / 1830) loss: 1.659476
# (Iteration 51 / 1830) loss: 1.606291
# (Iteration 61 / 1830) loss: 1.212976
# (Iteration 71 / 1830) loss: 1.048617
# (Iteration 81 / 1830) loss: 1.161549
# (Iteration 91 / 1830) loss: 0.880794
# (Iteration 101 / 1830) loss: 1.077170
# (Iteration 111 / 1830) loss: 0.870584
# (Iteration 121 / 1830) loss: 0.640639
# (Epoch 1 / 15) train RMS error: 0.897414; val RMS error: 1.231230
# (Iteration 131 / 1830) loss: 0.693382
# (Iteration 141 / 1830) loss: 0.704139
# (Iteration 151 / 1830) loss: 0.714919
# (Iteration 161 / 1830) loss: 0.771376
# (Iteration 171 / 1830) loss: 0.652091
# (Iteration 181 / 1830) loss: 0.702516
# (Iteration 191 / 1830) loss: 0.566750
# (Iteration 201 / 1830) loss: 0.589320
# (Iteration 211 / 1830) loss: 0.637027
# (Iteration 221 / 1830) loss: 0.564016
# (Iteration 231 / 1830) loss: 0.543258
# (Iteration 241 / 1830) loss: 0.579739
# (Epoch 2 / 15) train RMS error: 0.766639; val RMS error: 1.018426
# (Iteration 251 / 1830) loss: 0.558658
# (Iteration 261 / 1830) loss: 0.717599
# (Iteration 271 / 1830) loss: 0.720899
# (Iteration 281 / 1830) loss: 0.600003
# (Iteration 291 / 1830) loss: 0.661430
# (Iteration 301 / 1830) loss: 0.563764
# (Iteration 311 / 1830) loss: 0.684068
# (Iteration 321 / 1830) loss: 0.732498
# (Iteration 331 / 1830) loss: 0.681335
# (Iteration 341 / 1830) loss: 0.656881
# (Iteration 351 / 1830) loss: 0.599163
# (Iteration 361 / 1830) loss: 0.653024
# (Epoch 3 / 15) train RMS error: 0.740893; val RMS error: 0.999348
# (Iteration 371 / 1830) loss: 0.564277
# (Iteration 381 / 1830) loss: 0.491912
# (Iteration 391 / 1830) loss: 0.658427
# (Iteration 401 / 1830) loss: 0.624923
# (Iteration 411 / 1830) loss: 0.724769
# (Iteration 421 / 1830) loss: 0.528843
# (Iteration 431 / 1830) loss: 0.553750
# (Iteration 441 / 1830) loss: 0.571863
# (Iteration 451 / 1830) loss: 0.589549
# (Iteration 461 / 1830) loss: 0.532466
# (Iteration 471 / 1830) loss: 0.646411
# (Iteration 481 / 1830) loss: 0.801394
# (Epoch 4 / 15) train RMS error: 0.759667; val RMS error: 0.967686
# (Iteration 491 / 1830) loss: 0.592787
# (Iteration 501 / 1830) loss: 0.555953
# (Iteration 511 / 1830) loss: 0.579998
# (Iteration 521 / 1830) loss: 0.552734
# (Iteration 531 / 1830) loss: 0.537587
# (Iteration 541 / 1830) loss: 0.515016
# (Iteration 551 / 1830) loss: 0.564318
# (Iteration 561 / 1830) loss: 0.593677
# (Iteration 571 / 1830) loss: 0.562066
# (Iteration 581 / 1830) loss: 0.531855
# (Iteration 591 / 1830) loss: 0.493511
# (Iteration 601 / 1830) loss: 0.446306
# (Epoch 5 / 15) train RMS error: 0.739248; val RMS error: 0.933723
# (Iteration 611 / 1830) loss: 0.468424
# (Iteration 621 / 1830) loss: 0.458434
# (Iteration 631 / 1830) loss: 0.525166
# (Iteration 641 / 1830) loss: 0.515155
# (Iteration 651 / 1830) loss: 0.496191
# (Iteration 661 / 1830) loss: 0.609428
# (Iteration 671 / 1830) loss: 0.622460
# (Iteration 681 / 1830) loss: 0.449529
# (Iteration 691 / 1830) loss: 0.525457
# (Iteration 701 / 1830) loss: 0.569137
# (Iteration 711 / 1830) loss: 0.439855
# (Iteration 721 / 1830) loss: 0.439114
# (Iteration 731 / 1830) loss: 0.411848
# (Epoch 6 / 15) train RMS error: 0.626231; val RMS error: 0.861569
# (Iteration 741 / 1830) loss: 0.475800
# (Iteration 751 / 1830) loss: 0.367170
# (Iteration 761 / 1830) loss: 0.410667
# (Iteration 771 / 1830) loss: 0.396327
# (Iteration 781 / 1830) loss: 0.402229
# (Iteration 791 / 1830) loss: 0.300975
# (Iteration 801 / 1830) loss: 0.322413
# (Iteration 811 / 1830) loss: 0.303142
# (Iteration 821 / 1830) loss: 0.291962
# (Iteration 831 / 1830) loss: 0.314527
# (Iteration 841 / 1830) loss: 0.274051
# (Iteration 851 / 1830) loss: 0.347243
# (Epoch 7 / 15) train RMS error: 0.610492; val RMS error: 0.816773
# (Iteration 861 / 1830) loss: 0.435245
# (Iteration 871 / 1830) loss: 0.331217
# (Iteration 881 / 1830) loss: 0.267667
# (Iteration 891 / 1830) loss: 0.301419
# (Iteration 901 / 1830) loss: 0.321695
# (Iteration 911 / 1830) loss: 0.301407
# (Iteration 921 / 1830) loss: 0.301954
# (Iteration 931 / 1830) loss: 0.317074
# (Iteration 941 / 1830) loss: 0.312064
# (Iteration 951 / 1830) loss: 0.330479
# (Iteration 961 / 1830) loss: 0.337362
# (Iteration 971 / 1830) loss: 0.317860
# (Epoch 8 / 15) train RMS error: 0.601681; val RMS error: 0.790863
# (Iteration 981 / 1830) loss: 0.315157
# (Iteration 991 / 1830) loss: 0.338125
# (Iteration 1001 / 1830) loss: 0.269213
# (Iteration 1011 / 1830) loss: 0.309074
# (Iteration 1021 / 1830) loss: 0.244539
# (Iteration 1031 / 1830) loss: 0.355477
# (Iteration 1041 / 1830) loss: 0.289982
# (Iteration 1051 / 1830) loss: 0.277921
# (Iteration 1061 / 1830) loss: 0.443180
# (Iteration 1071 / 1830) loss: 0.383249
# (Iteration 1081 / 1830) loss: 0.329801
# (Iteration 1091 / 1830) loss: 0.274999
# (Epoch 9 / 15) train RMS error: 0.577789; val RMS error: 0.771057
# (Iteration 1101 / 1830) loss: 0.287704
# (Iteration 1111 / 1830) loss: 0.332046
# (Iteration 1121 / 1830) loss: 0.429228
# (Iteration 1131 / 1830) loss: 0.326114
# (Iteration 1141 / 1830) loss: 0.343148
# (Iteration 1151 / 1830) loss: 0.443096
# (Iteration 1161 / 1830) loss: 0.268928
# (Iteration 1171 / 1830) loss: 0.249005
# (Iteration 1181 / 1830) loss: 0.247645
# (Iteration 1191 / 1830) loss: 0.351934
# (Iteration 1201 / 1830) loss: 0.363516
# (Iteration 1211 / 1830) loss: 0.315958
# (Epoch 10 / 15) train RMS error: 0.573616; val RMS error: 0.755262
# (Iteration 1221 / 1830) loss: 0.427388
# (Iteration 1231 / 1830) loss: 0.395334
# (Iteration 1241 / 1830) loss: 0.304565
# (Iteration 1251 / 1830) loss: 0.308332
# (Iteration 1261 / 1830) loss: 0.309852
# (Iteration 1271 / 1830) loss: 0.250157
# (Iteration 1281 / 1830) loss: 0.323366
# (Iteration 1291 / 1830) loss: 0.330602
# (Iteration 1301 / 1830) loss: 0.252505
# (Iteration 1311 / 1830) loss: 0.294025
# (Iteration 1321 / 1830) loss: 0.303888
# (Iteration 1331 / 1830) loss: 0.196763
# (Iteration 1341 / 1830) loss: 0.337424
# (Epoch 11 / 15) train RMS error: 0.572330; val RMS error: 0.733964
# (Iteration 1351 / 1830) loss: 0.259315
# (Iteration 1361 / 1830) loss: 0.243858
# (Iteration 1371 / 1830) loss: 0.297779
# (Iteration 1381 / 1830) loss: 0.234549
# (Iteration 1391 / 1830) loss: 0.343165
# (Iteration 1401 / 1830) loss: 0.399498
# (Iteration 1411 / 1830) loss: 0.255156
# (Iteration 1421 / 1830) loss: 0.216999
# (Iteration 1431 / 1830) loss: 0.294057
# (Iteration 1441 / 1830) loss: 0.399029
# (Iteration 1451 / 1830) loss: 0.332186
# (Iteration 1461 / 1830) loss: 0.257862
# (Epoch 12 / 15) train RMS error: 0.553936; val RMS error: 0.728480
# (Iteration 1471 / 1830) loss: 0.292171
# (Iteration 1481 / 1830) loss: 0.301326
# (Iteration 1491 / 1830) loss: 0.291210
# (Iteration 1501 / 1830) loss: 0.267704
# (Iteration 1511 / 1830) loss: 0.332693
# (Iteration 1521 / 1830) loss: 0.227749
# (Iteration 1531 / 1830) loss: 0.256366
# (Iteration 1541 / 1830) loss: 0.198775
# (Iteration 1551 / 1830) loss: 0.288668
# (Iteration 1561 / 1830) loss: 0.296581
# (Iteration 1571 / 1830) loss: 0.282405
# (Iteration 1581 / 1830) loss: 0.267964
# (Epoch 13 / 15) train RMS error: 0.541789; val RMS error: 0.709667
# (Iteration 1591 / 1830) loss: 0.290420
# (Iteration 1601 / 1830) loss: 0.294940
# (Iteration 1611 / 1830) loss: 0.282988
# (Iteration 1621 / 1830) loss: 0.370319
# (Iteration 1631 / 1830) loss: 0.291390
# (Iteration 1641 / 1830) loss: 0.291652
# (Iteration 1651 / 1830) loss: 0.303209
# (Iteration 1661 / 1830) loss: 0.229435
# (Iteration 1671 / 1830) loss: 0.313493
# (Iteration 1681 / 1830) loss: 0.236995
# (Iteration 1691 / 1830) loss: 0.289556
# (Iteration 1701 / 1830) loss: 0.279369
# (Epoch 14 / 15) train RMS error: 0.570861; val RMS error: 0.705866
# (Iteration 1711 / 1830) loss: 0.306033
# (Iteration 1721 / 1830) loss: 0.266364
# (Iteration 1731 / 1830) loss: 0.247269
# (Iteration 1741 / 1830) loss: 0.285084
# (Iteration 1751 / 1830) loss: 0.299366
# (Iteration 1761 / 1830) loss: 0.217064
# (Iteration 1771 / 1830) loss: 0.257617
# (Iteration 1781 / 1830) loss: 0.264541
# (Iteration 1791 / 1830) loss: 0.194523
# (Iteration 1801 / 1830) loss: 0.401124
# (Iteration 1811 / 1830) loss: 0.197577
# (Iteration 1821 / 1830) loss: 0.200691
# (Epoch 15 / 15) train RMS error: 0.515155; val RMS error: 0.698398
# Validation RMS Error = 0.6984
#
# **** Training Structuire | Hidden Dims: [24, 96, 32] | LR: 0.001 ---
# (Iteration 1 / 1830) loss: 2.838913
# (Epoch 0 / 15) train RMS error: 1.610652; val RMS error: 2.111094
# (Iteration 11 / 1830) loss: 2.600338
# (Iteration 21 / 1830) loss: 2.049517
# (Iteration 31 / 1830) loss: 1.750193
# (Iteration 41 / 1830) loss: 1.120768
# (Iteration 51 / 1830) loss: 0.972281
# (Iteration 61 / 1830) loss: 0.821325
# (Iteration 71 / 1830) loss: 0.755943
# (Iteration 81 / 1830) loss: 0.731740
# (Iteration 91 / 1830) loss: 0.602767
# (Iteration 101 / 1830) loss: 0.875285
# (Iteration 111 / 1830) loss: 0.635088
# (Iteration 121 / 1830) loss: 0.817635
# (Epoch 1 / 15) train RMS error: 0.844318; val RMS error: 1.003264
# (Iteration 131 / 1830) loss: 0.717461
# (Iteration 141 / 1830) loss: 0.775060
# (Iteration 151 / 1830) loss: 0.612310
# (Iteration 161 / 1830) loss: 0.657304
# (Iteration 171 / 1830) loss: 0.500431
# (Iteration 181 / 1830) loss: 0.649618
# (Iteration 191 / 1830) loss: 0.774067
# (Iteration 201 / 1830) loss: 0.591461
# (Iteration 211 / 1830) loss: 0.765877
# (Iteration 221 / 1830) loss: 0.847439
# (Iteration 231 / 1830) loss: 0.562909
# (Iteration 241 / 1830) loss: 0.532487
# (Epoch 2 / 15) train RMS error: 0.836499; val RMS error: 1.028932
# (Iteration 251 / 1830) loss: 0.678530
# (Iteration 261 / 1830) loss: 0.574276
# (Iteration 271 / 1830) loss: 0.609730
# (Iteration 281 / 1830) loss: 0.853381
# (Iteration 291 / 1830) loss: 0.804675
# (Iteration 301 / 1830) loss: 0.575299
# (Iteration 311 / 1830) loss: 0.629524
# (Iteration 321 / 1830) loss: 0.719045
# (Iteration 331 / 1830) loss: 0.622533
# (Iteration 341 / 1830) loss: 0.602840
# (Iteration 351 / 1830) loss: 0.623478
# (Iteration 361 / 1830) loss: 0.637570
# (Epoch 3 / 15) train RMS error: 0.828679; val RMS error: 1.022578
# (Iteration 371 / 1830) loss: 0.831751
# (Iteration 381 / 1830) loss: 0.567509
# (Iteration 391 / 1830) loss: 0.701196
# (Iteration 401 / 1830) loss: 0.779824
# (Iteration 411 / 1830) loss: 0.689110
# (Iteration 421 / 1830) loss: 0.611481
# (Iteration 431 / 1830) loss: 0.691191
# (Iteration 441 / 1830) loss: 0.527936
# (Iteration 451 / 1830) loss: 0.717845
# (Iteration 461 / 1830) loss: 0.786085
# (Iteration 471 / 1830) loss: 0.694891
# (Iteration 481 / 1830) loss: 0.685105
# (Epoch 4 / 15) train RMS error: 0.822732; val RMS error: 1.010781
# (Iteration 491 / 1830) loss: 0.760989
# (Iteration 501 / 1830) loss: 0.543092
# (Iteration 511 / 1830) loss: 0.677763
# (Iteration 521 / 1830) loss: 0.664511
# (Iteration 531 / 1830) loss: 0.704636
# (Iteration 541 / 1830) loss: 0.812637
# (Iteration 551 / 1830) loss: 0.599467
# (Iteration 561 / 1830) loss: 0.525744
# (Iteration 571 / 1830) loss: 0.819364
# (Iteration 581 / 1830) loss: 0.715569
# (Iteration 591 / 1830) loss: 0.736649
# (Iteration 601 / 1830) loss: 0.750476
# (Epoch 5 / 15) train RMS error: 0.824526; val RMS error: 0.985907
# (Iteration 611 / 1830) loss: 0.641652
# (Iteration 621 / 1830) loss: 0.614328
# (Iteration 631 / 1830) loss: 0.661745
# (Iteration 641 / 1830) loss: 0.581170
# (Iteration 651 / 1830) loss: 0.489934
# (Iteration 661 / 1830) loss: 0.666572
# (Iteration 671 / 1830) loss: 0.568258
# (Iteration 681 / 1830) loss: 0.437538
# (Iteration 691 / 1830) loss: 0.489809
# (Iteration 701 / 1830) loss: 0.527907
# (Iteration 711 / 1830) loss: 0.563704
# (Iteration 721 / 1830) loss: 0.636663
# (Iteration 731 / 1830) loss: 0.426520
# (Epoch 6 / 15) train RMS error: 0.717307; val RMS error: 0.886974
# (Iteration 741 / 1830) loss: 0.326786
# (Iteration 751 / 1830) loss: 0.512520
# (Iteration 761 / 1830) loss: 0.415772
# (Iteration 771 / 1830) loss: 0.453674
# (Iteration 781 / 1830) loss: 0.478204
# (Iteration 791 / 1830) loss: 0.384807
# (Iteration 801 / 1830) loss: 0.484079
# (Iteration 811 / 1830) loss: 0.457084
# (Iteration 821 / 1830) loss: 0.401046
# (Iteration 831 / 1830) loss: 0.428017
# (Iteration 841 / 1830) loss: 0.305420
# (Iteration 851 / 1830) loss: 0.361727
# (Epoch 7 / 15) train RMS error: 0.640972; val RMS error: 0.800927
# (Iteration 861 / 1830) loss: 0.289784
# (Iteration 871 / 1830) loss: 0.353840
# (Iteration 881 / 1830) loss: 0.405698
# (Iteration 891 / 1830) loss: 0.425181
# (Iteration 901 / 1830) loss: 0.332580
# (Iteration 911 / 1830) loss: 0.353648
# (Iteration 921 / 1830) loss: 0.458748
# (Iteration 931 / 1830) loss: 0.317591
# (Iteration 941 / 1830) loss: 0.278084
# (Iteration 951 / 1830) loss: 0.394147
# (Iteration 961 / 1830) loss: 0.316435
# (Iteration 971 / 1830) loss: 0.359108
# (Epoch 8 / 15) train RMS error: 0.588735; val RMS error: 0.762314
# (Iteration 981 / 1830) loss: 0.336211
# (Iteration 991 / 1830) loss: 0.377693
# (Iteration 1001 / 1830) loss: 0.361037
# (Iteration 1011 / 1830) loss: 0.451852
# (Iteration 1021 / 1830) loss: 0.238924
# (Iteration 1031 / 1830) loss: 0.328402
# (Iteration 1041 / 1830) loss: 0.290614
# (Iteration 1051 / 1830) loss: 0.282894
# (Iteration 1061 / 1830) loss: 0.328610
# (Iteration 1071 / 1830) loss: 0.393661
# (Iteration 1081 / 1830) loss: 0.405379
# (Iteration 1091 / 1830) loss: 0.335841
# (Epoch 9 / 15) train RMS error: 0.590805; val RMS error: 0.726071
# (Iteration 1101 / 1830) loss: 0.416171
# (Iteration 1111 / 1830) loss: 0.308530
# (Iteration 1121 / 1830) loss: 0.255360
# (Iteration 1131 / 1830) loss: 0.278972
# (Iteration 1141 / 1830) loss: 0.376108
# (Iteration 1151 / 1830) loss: 0.362697
# (Iteration 1161 / 1830) loss: 0.227545
# (Iteration 1171 / 1830) loss: 0.293178
# (Iteration 1181 / 1830) loss: 0.380760
# (Iteration 1191 / 1830) loss: 0.253318
# (Iteration 1201 / 1830) loss: 0.307157
# (Iteration 1211 / 1830) loss: 0.288854
# (Epoch 10 / 15) train RMS error: 0.573752; val RMS error: 0.717044
# (Iteration 1221 / 1830) loss: 0.373262
# (Iteration 1231 / 1830) loss: 0.415189
# (Iteration 1241 / 1830) loss: 0.307275
# (Iteration 1251 / 1830) loss: 0.272013
# (Iteration 1261 / 1830) loss: 0.296302
# (Iteration 1271 / 1830) loss: 0.365561
# (Iteration 1281 / 1830) loss: 0.290166
# (Iteration 1291 / 1830) loss: 0.279608
# (Iteration 1301 / 1830) loss: 0.252514
# (Iteration 1311 / 1830) loss: 0.308000
# (Iteration 1321 / 1830) loss: 0.328647
# (Iteration 1331 / 1830) loss: 0.331451
# (Iteration 1341 / 1830) loss: 0.304570
# (Epoch 11 / 15) train RMS error: 0.572046; val RMS error: 0.688577
# (Iteration 1351 / 1830) loss: 0.334004
# (Iteration 1361 / 1830) loss: 0.316128
# (Iteration 1371 / 1830) loss: 0.294482
# (Iteration 1381 / 1830) loss: 0.270393
# (Iteration 1391 / 1830) loss: 0.322371
# (Iteration 1401 / 1830) loss: 0.290674
# (Iteration 1411 / 1830) loss: 0.235648
# (Iteration 1421 / 1830) loss: 0.299990
# (Iteration 1431 / 1830) loss: 0.269553
# (Iteration 1441 / 1830) loss: 0.307241
# (Iteration 1451 / 1830) loss: 0.298991
# (Iteration 1461 / 1830) loss: 0.277344
# (Epoch 12 / 15) train RMS error: 0.555139; val RMS error: 0.675956
# (Iteration 1471 / 1830) loss: 0.278210
# (Iteration 1481 / 1830) loss: 0.248678
# (Iteration 1491 / 1830) loss: 0.283704
# (Iteration 1501 / 1830) loss: 0.290136
# (Iteration 1511 / 1830) loss: 0.291207
# (Iteration 1521 / 1830) loss: 0.326441
# (Iteration 1531 / 1830) loss: 0.249771
# (Iteration 1541 / 1830) loss: 0.370612
# (Iteration 1551 / 1830) loss: 0.257241
# (Iteration 1561 / 1830) loss: 0.354688
# (Iteration 1571 / 1830) loss: 0.319637
# (Iteration 1581 / 1830) loss: 0.223977
# (Epoch 13 / 15) train RMS error: 0.533936; val RMS error: 0.666072
# (Iteration 1591 / 1830) loss: 0.230251
# (Iteration 1601 / 1830) loss: 0.194377
# (Iteration 1611 / 1830) loss: 0.339027
# (Iteration 1621 / 1830) loss: 0.322530
# (Iteration 1631 / 1830) loss: 0.340961
# (Iteration 1641 / 1830) loss: 0.251442
# (Iteration 1651 / 1830) loss: 0.230964
# (Iteration 1661 / 1830) loss: 0.244211
# (Iteration 1671 / 1830) loss: 0.251266
# (Iteration 1681 / 1830) loss: 0.244501
# (Iteration 1691 / 1830) loss: 0.240863
# (Iteration 1701 / 1830) loss: 0.299554
# (Epoch 14 / 15) train RMS error: 0.546723; val RMS error: 0.642797
# (Iteration 1711 / 1830) loss: 0.371575
# (Iteration 1721 / 1830) loss: 0.267722
# (Iteration 1731 / 1830) loss: 0.289303
# (Iteration 1741 / 1830) loss: 0.335898
# (Iteration 1751 / 1830) loss: 0.337057
# (Iteration 1761 / 1830) loss: 0.272084
# (Iteration 1771 / 1830) loss: 0.306328
# (Iteration 1781 / 1830) loss: 0.290994
# (Iteration 1791 / 1830) loss: 0.333398
# (Iteration 1801 / 1830) loss: 0.322785
# (Iteration 1811 / 1830) loss: 0.264944
# (Iteration 1821 / 1830) loss: 0.263422
# (Epoch 15 / 15) train RMS error: 0.522342; val RMS error: 0.630518
# Validation RMS Error = 0.6305
#
# **** Training Structuire | Hidden Dims: [24, 96, 32] | LR: 0.0005 ---
# (Iteration 1 / 1830) loss: 2.434065
# (Epoch 0 / 15) train RMS error: 1.656735; val RMS error: 2.113861
# (Iteration 11 / 1830) loss: 2.491744
# (Iteration 21 / 1830) loss: 1.965622
# (Iteration 31 / 1830) loss: 1.995280
# (Iteration 41 / 1830) loss: 1.897709
# (Iteration 51 / 1830) loss: 1.733343
# (Iteration 61 / 1830) loss: 1.652926
# (Iteration 71 / 1830) loss: 1.241634
# (Iteration 81 / 1830) loss: 0.873214
# (Iteration 91 / 1830) loss: 1.079429
# (Iteration 101 / 1830) loss: 0.889788
# (Iteration 111 / 1830) loss: 0.712833
# (Iteration 121 / 1830) loss: 0.781141
# (Epoch 1 / 15) train RMS error: 0.923149; val RMS error: 1.243642
# (Iteration 131 / 1830) loss: 0.843024
# (Iteration 141 / 1830) loss: 0.649222
# (Iteration 151 / 1830) loss: 0.790220
# (Iteration 161 / 1830) loss: 0.780178
# (Iteration 171 / 1830) loss: 0.782202
# (Iteration 181 / 1830) loss: 0.709628
# (Iteration 191 / 1830) loss: 0.772999
# (Iteration 201 / 1830) loss: 0.624512
# (Iteration 211 / 1830) loss: 0.669130
# (Iteration 221 / 1830) loss: 0.654034
# (Iteration 231 / 1830) loss: 0.679776
# (Iteration 241 / 1830) loss: 0.670796
# (Epoch 2 / 15) train RMS error: 0.817362; val RMS error: 1.036681
# (Iteration 251 / 1830) loss: 0.782979
# (Iteration 261 / 1830) loss: 0.633269
# (Iteration 271 / 1830) loss: 0.609215
# (Iteration 281 / 1830) loss: 0.532807
# (Iteration 291 / 1830) loss: 0.633864
# (Iteration 301 / 1830) loss: 0.781929
# (Iteration 311 / 1830) loss: 0.754137
# (Iteration 321 / 1830) loss: 0.786043
# (Iteration 331 / 1830) loss: 0.815960
# (Iteration 341 / 1830) loss: 0.558465
# (Iteration 351 / 1830) loss: 0.738158
# (Iteration 361 / 1830) loss: 0.719686
# (Epoch 3 / 15) train RMS error: 0.839746; val RMS error: 1.022462
# (Iteration 371 / 1830) loss: 0.582681
# (Iteration 381 / 1830) loss: 0.710046
# (Iteration 391 / 1830) loss: 0.762390
# (Iteration 401 / 1830) loss: 0.608491
# (Iteration 411 / 1830) loss: 0.575753
# (Iteration 421 / 1830) loss: 0.546420
# (Iteration 431 / 1830) loss: 0.755226
# (Iteration 441 / 1830) loss: 0.793547
# (Iteration 451 / 1830) loss: 0.825262
# (Iteration 461 / 1830) loss: 0.701644
# (Iteration 471 / 1830) loss: 0.647781
# (Iteration 481 / 1830) loss: 0.595975
# (Epoch 4 / 15) train RMS error: 0.835880; val RMS error: 1.020404
# (Iteration 491 / 1830) loss: 0.737861
# (Iteration 501 / 1830) loss: 0.693631
# (Iteration 511 / 1830) loss: 0.657607
# (Iteration 521 / 1830) loss: 0.717750
# (Iteration 531 / 1830) loss: 0.605308
# (Iteration 541 / 1830) loss: 0.538388
# (Iteration 551 / 1830) loss: 0.677172
# (Iteration 561 / 1830) loss: 0.592035
# (Iteration 571 / 1830) loss: 0.977244
# (Iteration 581 / 1830) loss: 0.604445
# (Iteration 591 / 1830) loss: 0.724899
# (Iteration 601 / 1830) loss: 0.668713
# (Epoch 5 / 15) train RMS error: 0.819571; val RMS error: 1.024371
# (Iteration 611 / 1830) loss: 0.604423
# (Iteration 621 / 1830) loss: 0.758850
# (Iteration 631 / 1830) loss: 0.590528
# (Iteration 641 / 1830) loss: 0.569413
# (Iteration 651 / 1830) loss: 0.684501
# (Iteration 661 / 1830) loss: 0.445942
# (Iteration 671 / 1830) loss: 0.741318
# (Iteration 681 / 1830) loss: 0.623837
# (Iteration 691 / 1830) loss: 0.609791
# (Iteration 701 / 1830) loss: 0.679223
# (Iteration 711 / 1830) loss: 0.519532
# (Iteration 721 / 1830) loss: 0.442618
# (Iteration 731 / 1830) loss: 0.720141
# (Epoch 6 / 15) train RMS error: 0.798160; val RMS error: 1.022820
# (Iteration 741 / 1830) loss: 0.788181
# (Iteration 751 / 1830) loss: 0.606405
# (Iteration 761 / 1830) loss: 0.618907
# (Iteration 771 / 1830) loss: 0.613126
# (Iteration 781 / 1830) loss: 0.680055
# (Iteration 791 / 1830) loss: 0.691344
# (Iteration 801 / 1830) loss: 0.572160
# (Iteration 811 / 1830) loss: 0.682606
# (Iteration 821 / 1830) loss: 0.579636
# (Iteration 831 / 1830) loss: 0.630311
# (Iteration 841 / 1830) loss: 0.618275
# (Iteration 851 / 1830) loss: 0.521098
# (Epoch 7 / 15) train RMS error: 0.837487; val RMS error: 1.010393
# (Iteration 861 / 1830) loss: 0.718030
# (Iteration 871 / 1830) loss: 0.545648
# (Iteration 881 / 1830) loss: 0.679732
# (Iteration 891 / 1830) loss: 0.627187
# (Iteration 901 / 1830) loss: 0.597930
# (Iteration 911 / 1830) loss: 0.668905
# (Iteration 921 / 1830) loss: 0.629726
# (Iteration 931 / 1830) loss: 0.564183
# (Iteration 941 / 1830) loss: 0.736938
# (Iteration 951 / 1830) loss: 0.650237
# (Iteration 961 / 1830) loss: 0.635940
# (Iteration 971 / 1830) loss: 0.584440
# (Epoch 8 / 15) train RMS error: 0.793184; val RMS error: 1.000485
# (Iteration 981 / 1830) loss: 0.569656
# (Iteration 991 / 1830) loss: 0.578440
# (Iteration 1001 / 1830) loss: 0.629552
# (Iteration 1011 / 1830) loss: 0.594032
# (Iteration 1021 / 1830) loss: 0.658528
# (Iteration 1031 / 1830) loss: 0.556302
# (Iteration 1041 / 1830) loss: 0.673207
# (Iteration 1051 / 1830) loss: 0.655328
# (Iteration 1061 / 1830) loss: 0.686417
# (Iteration 1071 / 1830) loss: 0.702100
# (Iteration 1081 / 1830) loss: 0.817374
# (Iteration 1091 / 1830) loss: 0.531938
# (Epoch 9 / 15) train RMS error: 0.779585; val RMS error: 0.973729
# (Iteration 1101 / 1830) loss: 0.679993
# (Iteration 1111 / 1830) loss: 0.536673
# (Iteration 1121 / 1830) loss: 0.646543
# (Iteration 1131 / 1830) loss: 0.518747
# (Iteration 1141 / 1830) loss: 0.644524
# (Iteration 1151 / 1830) loss: 0.588397
# (Iteration 1161 / 1830) loss: 0.667534
# (Iteration 1171 / 1830) loss: 0.515801
# (Iteration 1181 / 1830) loss: 0.525888
# (Iteration 1191 / 1830) loss: 0.558009
# (Iteration 1201 / 1830) loss: 0.571221
# (Iteration 1211 / 1830) loss: 0.562940
# (Epoch 10 / 15) train RMS error: 0.770738; val RMS error: 0.921176
# (Iteration 1221 / 1830) loss: 0.516332
# (Iteration 1231 / 1830) loss: 0.475107
# (Iteration 1241 / 1830) loss: 0.568482
# (Iteration 1251 / 1830) loss: 0.465449
# (Iteration 1261 / 1830) loss: 0.469544
# (Iteration 1271 / 1830) loss: 0.529837
# (Iteration 1281 / 1830) loss: 0.501024
# (Iteration 1291 / 1830) loss: 0.440819
# (Iteration 1301 / 1830) loss: 0.472497
# (Iteration 1311 / 1830) loss: 0.504644
# (Iteration 1321 / 1830) loss: 0.599174
# (Iteration 1331 / 1830) loss: 0.349158
# (Iteration 1341 / 1830) loss: 0.489522
# (Epoch 11 / 15) train RMS error: 0.649050; val RMS error: 0.846186
# (Iteration 1351 / 1830) loss: 0.410742
# (Iteration 1361 / 1830) loss: 0.416659
# (Iteration 1371 / 1830) loss: 0.429146
# (Iteration 1381 / 1830) loss: 0.360683
# (Iteration 1391 / 1830) loss: 0.431089
# (Iteration 1401 / 1830) loss: 0.430668
# (Iteration 1411 / 1830) loss: 0.429386
# (Iteration 1421 / 1830) loss: 0.346753
# (Iteration 1431 / 1830) loss: 0.381008
# (Iteration 1441 / 1830) loss: 0.423736
# (Iteration 1451 / 1830) loss: 0.353639
# (Iteration 1461 / 1830) loss: 0.404053
# (Epoch 12 / 15) train RMS error: 0.601782; val RMS error: 0.813571
# (Iteration 1471 / 1830) loss: 0.342391
# (Iteration 1481 / 1830) loss: 0.459273
# (Iteration 1491 / 1830) loss: 0.350861
# (Iteration 1501 / 1830) loss: 0.272350
# (Iteration 1511 / 1830) loss: 0.411557
# (Iteration 1521 / 1830) loss: 0.378801
# (Iteration 1531 / 1830) loss: 0.381983
# (Iteration 1541 / 1830) loss: 0.404514
# (Iteration 1551 / 1830) loss: 0.340234
# (Iteration 1561 / 1830) loss: 0.423852
# (Iteration 1571 / 1830) loss: 0.341780
# (Iteration 1581 / 1830) loss: 0.424278
# (Epoch 13 / 15) train RMS error: 0.604332; val RMS error: 0.783248
# (Iteration 1591 / 1830) loss: 0.425472
# (Iteration 1601 / 1830) loss: 0.468596
# (Iteration 1611 / 1830) loss: 0.327041
# (Iteration 1621 / 1830) loss: 0.366968
# (Iteration 1631 / 1830) loss: 0.311780
# (Iteration 1641 / 1830) loss: 0.440552
# (Iteration 1651 / 1830) loss: 0.347528
# (Iteration 1661 / 1830) loss: 0.396508
# (Iteration 1671 / 1830) loss: 0.391128
# (Iteration 1681 / 1830) loss: 0.426930
# (Iteration 1691 / 1830) loss: 0.458675
# (Iteration 1701 / 1830) loss: 0.347210
# (Epoch 14 / 15) train RMS error: 0.583155; val RMS error: 0.778130
# (Iteration 1711 / 1830) loss: 0.406204
# (Iteration 1721 / 1830) loss: 0.341808
# (Iteration 1731 / 1830) loss: 0.386048
# (Iteration 1741 / 1830) loss: 0.383584
# (Iteration 1751 / 1830) loss: 0.367749
# (Iteration 1761 / 1830) loss: 0.312863
# (Iteration 1771 / 1830) loss: 0.352063
# (Iteration 1781 / 1830) loss: 0.371743
# (Iteration 1791 / 1830) loss: 0.402212
# (Iteration 1801 / 1830) loss: 0.370742
# (Iteration 1811 / 1830) loss: 0.361617
# (Iteration 1821 / 1830) loss: 0.405986
# (Epoch 15 / 15) train RMS error: 0.612712; val RMS error: 0.763652
# Validation RMS Error = 0.7637
#
# **** Training Structuire | Hidden Dims: [32, 128, 64, 32] | LR: 0.001 ---
# (Iteration 1 / 1830) loss: 2.346811
# (Epoch 0 / 15) train RMS error: 1.703336; val RMS error: 2.139111
# (Iteration 11 / 1830) loss: 2.305769
# (Iteration 21 / 1830) loss: 2.321657
# (Iteration 31 / 1830) loss: 1.641632
# (Iteration 41 / 1830) loss: 1.097086
# (Iteration 51 / 1830) loss: 1.045920
# (Iteration 61 / 1830) loss: 0.813806
# (Iteration 71 / 1830) loss: 0.763286
# (Iteration 81 / 1830) loss: 1.073063
# (Iteration 91 / 1830) loss: 1.074966
# (Iteration 101 / 1830) loss: 0.828317
# (Iteration 111 / 1830) loss: 0.758793
# (Iteration 121 / 1830) loss: 0.634036
# (Epoch 1 / 15) train RMS error: 0.899909; val RMS error: 1.070690
# (Iteration 131 / 1830) loss: 0.644667
# (Iteration 141 / 1830) loss: 0.924649
# (Iteration 151 / 1830) loss: 0.923563
# (Iteration 161 / 1830) loss: 0.850575
# (Iteration 171 / 1830) loss: 1.046181
# (Iteration 181 / 1830) loss: 0.679010
# (Iteration 191 / 1830) loss: 0.754350
# (Iteration 201 / 1830) loss: 0.848120
# (Iteration 211 / 1830) loss: 0.719314
# (Iteration 221 / 1830) loss: 0.728516
# (Iteration 231 / 1830) loss: 0.837082
# (Iteration 241 / 1830) loss: 0.748540
# (Epoch 2 / 15) train RMS error: 0.904855; val RMS error: 1.073018
# (Iteration 251 / 1830) loss: 0.870156
# (Iteration 261 / 1830) loss: 0.861240
# (Iteration 271 / 1830) loss: 0.840006
# (Iteration 281 / 1830) loss: 0.803613
# (Iteration 291 / 1830) loss: 0.770952
# (Iteration 301 / 1830) loss: 0.664899
# (Iteration 311 / 1830) loss: 0.749346
# (Iteration 321 / 1830) loss: 0.653886
# (Iteration 331 / 1830) loss: 0.611221
# (Iteration 341 / 1830) loss: 0.775591
# (Iteration 351 / 1830) loss: 0.807800
# (Iteration 361 / 1830) loss: 0.723597
# (Epoch 3 / 15) train RMS error: 0.889322; val RMS error: 1.076822
# (Iteration 371 / 1830) loss: 0.847206
# (Iteration 381 / 1830) loss: 0.776104
# (Iteration 391 / 1830) loss: 0.647585
# (Iteration 401 / 1830) loss: 0.633168
# (Iteration 411 / 1830) loss: 0.765759
# (Iteration 421 / 1830) loss: 0.824124
# (Iteration 431 / 1830) loss: 0.886458
# (Iteration 441 / 1830) loss: 0.960202
# (Iteration 451 / 1830) loss: 0.784099
# (Iteration 461 / 1830) loss: 0.637765
# (Iteration 471 / 1830) loss: 0.693862
# (Iteration 481 / 1830) loss: 0.907533
# (Epoch 4 / 15) train RMS error: 0.889379; val RMS error: 1.066340
# (Iteration 491 / 1830) loss: 0.611968
# (Iteration 501 / 1830) loss: 0.692624
# (Iteration 511 / 1830) loss: 0.771203
# (Iteration 521 / 1830) loss: 0.787692
# (Iteration 531 / 1830) loss: 0.828475
# (Iteration 541 / 1830) loss: 0.785244
# (Iteration 551 / 1830) loss: 0.775252
# (Iteration 561 / 1830) loss: 0.671671
# (Iteration 571 / 1830) loss: 0.727270
# (Iteration 581 / 1830) loss: 0.664206
# (Iteration 591 / 1830) loss: 0.634008
# (Iteration 601 / 1830) loss: 0.689664
# (Epoch 5 / 15) train RMS error: 0.908052; val RMS error: 1.067852
# (Iteration 611 / 1830) loss: 0.708184
# (Iteration 621 / 1830) loss: 0.620187
# (Iteration 631 / 1830) loss: 0.829737
# (Iteration 641 / 1830) loss: 0.842207
# (Iteration 651 / 1830) loss: 0.694315
# (Iteration 661 / 1830) loss: 0.773818
# (Iteration 671 / 1830) loss: 0.736353
# (Iteration 681 / 1830) loss: 0.813582
# (Iteration 691 / 1830) loss: 0.860903
# (Iteration 701 / 1830) loss: 0.844188
# (Iteration 711 / 1830) loss: 0.750030
# (Iteration 721 / 1830) loss: 0.616892
# (Iteration 731 / 1830) loss: 0.768368
# (Epoch 6 / 15) train RMS error: 0.863782; val RMS error: 1.059174
# (Iteration 741 / 1830) loss: 0.873857
# (Iteration 751 / 1830) loss: 0.715777
# (Iteration 761 / 1830) loss: 0.680733
# (Iteration 771 / 1830) loss: 0.789836
# (Iteration 781 / 1830) loss: 0.690236
# (Iteration 791 / 1830) loss: 0.762872
# (Iteration 801 / 1830) loss: 0.738374
# (Iteration 811 / 1830) loss: 0.798133
# (Iteration 821 / 1830) loss: 0.848960
# (Iteration 831 / 1830) loss: 0.779907
# (Iteration 841 / 1830) loss: 0.810439
# (Iteration 851 / 1830) loss: 0.753423
# (Epoch 7 / 15) train RMS error: 0.872899; val RMS error: 1.060324
# (Iteration 861 / 1830) loss: 0.625426
# (Iteration 871 / 1830) loss: 0.726197
# (Iteration 881 / 1830) loss: 0.902438
# (Iteration 891 / 1830) loss: 0.710981
# (Iteration 901 / 1830) loss: 0.587191
# (Iteration 911 / 1830) loss: 0.600310
# (Iteration 921 / 1830) loss: 0.768514
# (Iteration 931 / 1830) loss: 0.673521
# (Iteration 941 / 1830) loss: 0.629336
# (Iteration 951 / 1830) loss: 0.758176
# (Iteration 961 / 1830) loss: 0.752801
# (Iteration 971 / 1830) loss: 0.700293
# (Epoch 8 / 15) train RMS error: 0.858905; val RMS error: 1.059378
# (Iteration 981 / 1830) loss: 0.766270
# (Iteration 991 / 1830) loss: 0.826225
# (Iteration 1001 / 1830) loss: 0.756610
# (Iteration 1011 / 1830) loss: 0.798976
# (Iteration 1021 / 1830) loss: 0.845621
# (Iteration 1031 / 1830) loss: 0.750206
# (Iteration 1041 / 1830) loss: 0.755954
# (Iteration 1051 / 1830) loss: 0.724983
# (Iteration 1061 / 1830) loss: 0.660387
# (Iteration 1071 / 1830) loss: 0.719283
# (Iteration 1081 / 1830) loss: 0.688285
# (Iteration 1091 / 1830) loss: 0.594923
# (Epoch 9 / 15) train RMS error: 0.868992; val RMS error: 1.050579
# (Iteration 1101 / 1830) loss: 0.739690
# (Iteration 1111 / 1830) loss: 0.793115
# (Iteration 1121 / 1830) loss: 0.659310
# (Iteration 1131 / 1830) loss: 0.766126
# (Iteration 1141 / 1830) loss: 0.745669
# (Iteration 1151 / 1830) loss: 0.653153
# (Iteration 1161 / 1830) loss: 0.891645
# (Iteration 1171 / 1830) loss: 0.761911
# (Iteration 1181 / 1830) loss: 0.795339
# (Iteration 1191 / 1830) loss: 0.731249
# (Iteration 1201 / 1830) loss: 0.785757
# (Iteration 1211 / 1830) loss: 0.703138
# (Epoch 10 / 15) train RMS error: 0.855994; val RMS error: 1.052867
# (Iteration 1221 / 1830) loss: 0.504035
# (Iteration 1231 / 1830) loss: 0.678938
# (Iteration 1241 / 1830) loss: 0.752442
# (Iteration 1251 / 1830) loss: 0.692717
# (Iteration 1261 / 1830) loss: 0.771418
# (Iteration 1271 / 1830) loss: 0.666244
# (Iteration 1281 / 1830) loss: 0.835532
# (Iteration 1291 / 1830) loss: 0.745140
# (Iteration 1301 / 1830) loss: 0.601746
# (Iteration 1311 / 1830) loss: 0.845746
# (Iteration 1321 / 1830) loss: 0.750925
# (Iteration 1331 / 1830) loss: 0.793128
# (Iteration 1341 / 1830) loss: 0.724186
# (Epoch 11 / 15) train RMS error: 0.867693; val RMS error: 1.046650
# (Iteration 1351 / 1830) loss: 0.737742
# (Iteration 1361 / 1830) loss: 0.865279
# (Iteration 1371 / 1830) loss: 0.957714
# (Iteration 1381 / 1830) loss: 0.730480
# (Iteration 1391 / 1830) loss: 0.875577
# (Iteration 1401 / 1830) loss: 0.700667
# (Iteration 1411 / 1830) loss: 0.680358
# (Iteration 1421 / 1830) loss: 0.670176
# (Iteration 1431 / 1830) loss: 0.619603
# (Iteration 1441 / 1830) loss: 0.959026
# (Iteration 1451 / 1830) loss: 0.709425
# (Iteration 1461 / 1830) loss: 0.616726
# (Epoch 12 / 15) train RMS error: 0.826760; val RMS error: 1.039576
# (Iteration 1471 / 1830) loss: 0.846711
# (Iteration 1481 / 1830) loss: 0.572051
# (Iteration 1491 / 1830) loss: 0.683819
# (Iteration 1501 / 1830) loss: 0.783308
# (Iteration 1511 / 1830) loss: 0.641403
# (Iteration 1521 / 1830) loss: 0.640938
# (Iteration 1531 / 1830) loss: 0.721715
# (Iteration 1541 / 1830) loss: 0.655019
# (Iteration 1551 / 1830) loss: 0.652303
# (Iteration 1561 / 1830) loss: 0.831898
# (Iteration 1571 / 1830) loss: 0.676946
# (Iteration 1581 / 1830) loss: 0.695855
# (Epoch 13 / 15) train RMS error: 0.901916; val RMS error: 1.036800
# (Iteration 1591 / 1830) loss: 0.610374
# (Iteration 1601 / 1830) loss: 0.691898
# (Iteration 1611 / 1830) loss: 0.619326
# (Iteration 1621 / 1830) loss: 0.876802
# (Iteration 1631 / 1830) loss: 0.662392
# (Iteration 1641 / 1830) loss: 0.805067
# (Iteration 1651 / 1830) loss: 0.777583
# (Iteration 1661 / 1830) loss: 0.662080
# (Iteration 1671 / 1830) loss: 0.514718
# (Iteration 1681 / 1830) loss: 0.658316
# (Iteration 1691 / 1830) loss: 0.614716
# (Iteration 1701 / 1830) loss: 0.677088
# (Epoch 14 / 15) train RMS error: 0.871341; val RMS error: 1.036378
# (Iteration 1711 / 1830) loss: 0.641544
# (Iteration 1721 / 1830) loss: 0.591671
# (Iteration 1731 / 1830) loss: 0.704146
# (Iteration 1741 / 1830) loss: 0.824661
# (Iteration 1751 / 1830) loss: 0.594080
# (Iteration 1761 / 1830) loss: 0.720463
# (Iteration 1771 / 1830) loss: 0.672302
# (Iteration 1781 / 1830) loss: 0.610101
# (Iteration 1791 / 1830) loss: 0.755890
# (Iteration 1801 / 1830) loss: 0.766619
# (Iteration 1811 / 1830) loss: 0.659969
# (Iteration 1821 / 1830) loss: 0.539346
# (Epoch 15 / 15) train RMS error: 0.815994; val RMS error: 1.020452
# Validation RMS Error = 1.0205
#
# **** Training Structuire | Hidden Dims: [32, 128, 64, 32] | LR: 0.0005 ---
# (Iteration 1 / 1830) loss: 2.865757
# (Epoch 0 / 15) train RMS error: 1.644684; val RMS error: 2.139693
# (Iteration 11 / 1830) loss: 2.669388
# (Iteration 21 / 1830) loss: 2.247807
# (Iteration 31 / 1830) loss: 1.743651
# (Iteration 41 / 1830) loss: 2.301933
# (Iteration 51 / 1830) loss: 1.257450
# (Iteration 61 / 1830) loss: 1.288901
# (Iteration 71 / 1830) loss: 1.354887
# (Iteration 81 / 1830) loss: 1.469486
# (Iteration 91 / 1830) loss: 1.306079
# (Iteration 101 / 1830) loss: 0.871200
# (Iteration 111 / 1830) loss: 0.803692
# (Iteration 121 / 1830) loss: 1.054261
# (Epoch 1 / 15) train RMS error: 0.939236; val RMS error: 1.257967
# (Iteration 131 / 1830) loss: 0.808065
# (Iteration 141 / 1830) loss: 1.022174
# (Iteration 151 / 1830) loss: 0.758596
# (Iteration 161 / 1830) loss: 0.844190
# (Iteration 171 / 1830) loss: 0.765250
# (Iteration 181 / 1830) loss: 0.945662
# (Iteration 191 / 1830) loss: 0.697128
# (Iteration 201 / 1830) loss: 0.883121
# (Iteration 211 / 1830) loss: 0.753809
# (Iteration 221 / 1830) loss: 0.935334
# (Iteration 231 / 1830) loss: 0.784255
# (Iteration 241 / 1830) loss: 0.707819
# (Epoch 2 / 15) train RMS error: 0.866790; val RMS error: 1.081689
# (Iteration 251 / 1830) loss: 0.764035
# (Iteration 261 / 1830) loss: 0.739604
# (Iteration 271 / 1830) loss: 0.766014
# (Iteration 281 / 1830) loss: 0.732046
# (Iteration 291 / 1830) loss: 0.698822
# (Iteration 301 / 1830) loss: 0.998181
# (Iteration 311 / 1830) loss: 0.777505
# (Iteration 321 / 1830) loss: 0.876908
# (Iteration 331 / 1830) loss: 0.731218
# (Iteration 341 / 1830) loss: 0.658369
# (Iteration 351 / 1830) loss: 0.850403
# (Iteration 361 / 1830) loss: 0.827717
# (Epoch 3 / 15) train RMS error: 0.854644; val RMS error: 1.078194
# (Iteration 371 / 1830) loss: 0.779860
# (Iteration 381 / 1830) loss: 0.624569
# (Iteration 391 / 1830) loss: 0.776514
# (Iteration 401 / 1830) loss: 0.995745
# (Iteration 411 / 1830) loss: 0.765704
# (Iteration 421 / 1830) loss: 0.657190
# (Iteration 431 / 1830) loss: 0.880551
# (Iteration 441 / 1830) loss: 0.872419
# (Iteration 451 / 1830) loss: 0.781659
# (Iteration 461 / 1830) loss: 0.915077
# (Iteration 471 / 1830) loss: 0.843769
# (Iteration 481 / 1830) loss: 0.891115
# (Epoch 4 / 15) train RMS error: 0.915216; val RMS error: 1.079098
# (Iteration 491 / 1830) loss: 0.882038
# (Iteration 501 / 1830) loss: 0.784281
# (Iteration 511 / 1830) loss: 0.776858
# (Iteration 521 / 1830) loss: 0.697187
# (Iteration 531 / 1830) loss: 0.766605
# (Iteration 541 / 1830) loss: 0.600427
# (Iteration 551 / 1830) loss: 0.748809
# (Iteration 561 / 1830) loss: 0.806004
# (Iteration 571 / 1830) loss: 0.610315
# (Iteration 581 / 1830) loss: 0.822773
# (Iteration 591 / 1830) loss: 0.766493
# (Iteration 601 / 1830) loss: 0.751500
# (Epoch 5 / 15) train RMS error: 0.872879; val RMS error: 1.081907
# (Iteration 611 / 1830) loss: 0.693407
# (Iteration 621 / 1830) loss: 0.871497
# (Iteration 631 / 1830) loss: 0.732601
# (Iteration 641 / 1830) loss: 0.782820
# (Iteration 651 / 1830) loss: 0.687082
# (Iteration 661 / 1830) loss: 0.783547
# (Iteration 671 / 1830) loss: 0.784031
# (Iteration 681 / 1830) loss: 0.776419
# (Iteration 691 / 1830) loss: 0.719309
# (Iteration 701 / 1830) loss: 0.887703
# (Iteration 711 / 1830) loss: 0.798660
# (Iteration 721 / 1830) loss: 0.752189
# (Iteration 731 / 1830) loss: 0.741942
# (Epoch 6 / 15) train RMS error: 0.922206; val RMS error: 1.075684
# (Iteration 741 / 1830) loss: 0.771843
# (Iteration 751 / 1830) loss: 0.687017
# (Iteration 761 / 1830) loss: 0.805014
# (Iteration 771 / 1830) loss: 0.812277
# (Iteration 781 / 1830) loss: 0.760293
# (Iteration 791 / 1830) loss: 0.812948
# (Iteration 801 / 1830) loss: 0.699331
# (Iteration 811 / 1830) loss: 0.797132
# (Iteration 821 / 1830) loss: 0.712889
# (Iteration 831 / 1830) loss: 0.874370
# (Iteration 841 / 1830) loss: 0.768699
# (Iteration 851 / 1830) loss: 0.863692
# (Epoch 7 / 15) train RMS error: 0.904861; val RMS error: 1.070351
# (Iteration 861 / 1830) loss: 0.800963
# (Iteration 871 / 1830) loss: 0.926785
# (Iteration 881 / 1830) loss: 0.814483
# (Iteration 891 / 1830) loss: 0.689345
# (Iteration 901 / 1830) loss: 0.837268
# (Iteration 911 / 1830) loss: 0.942423
# (Iteration 921 / 1830) loss: 0.698468
# (Iteration 931 / 1830) loss: 0.854977
# (Iteration 941 / 1830) loss: 0.803906
# (Iteration 951 / 1830) loss: 0.717588
# (Iteration 961 / 1830) loss: 0.656719
# (Iteration 971 / 1830) loss: 0.803857
# (Epoch 8 / 15) train RMS error: 0.875665; val RMS error: 1.064400
# (Iteration 981 / 1830) loss: 0.807760
# (Iteration 991 / 1830) loss: 0.818773
# (Iteration 1001 / 1830) loss: 0.878876
# (Iteration 1011 / 1830) loss: 0.745568
# (Iteration 1021 / 1830) loss: 0.713629
# (Iteration 1031 / 1830) loss: 0.818911
# (Iteration 1041 / 1830) loss: 0.822766
# (Iteration 1051 / 1830) loss: 0.677958
# (Iteration 1061 / 1830) loss: 0.938938
# (Iteration 1071 / 1830) loss: 0.625955
# (Iteration 1081 / 1830) loss: 0.791367
# (Iteration 1091 / 1830) loss: 0.835836
# (Epoch 9 / 15) train RMS error: 0.885182; val RMS error: 1.067338
# (Iteration 1101 / 1830) loss: 0.764127
# (Iteration 1111 / 1830) loss: 0.710194
# (Iteration 1121 / 1830) loss: 0.668461
# (Iteration 1131 / 1830) loss: 0.903511
# (Iteration 1141 / 1830) loss: 0.824310
# (Iteration 1151 / 1830) loss: 0.687286
# (Iteration 1161 / 1830) loss: 0.773949
# (Iteration 1171 / 1830) loss: 0.975320
# (Iteration 1181 / 1830) loss: 0.739792
# (Iteration 1191 / 1830) loss: 0.682319
# (Iteration 1201 / 1830) loss: 0.834218
# (Iteration 1211 / 1830) loss: 0.811504
# (Epoch 10 / 15) train RMS error: 0.887706; val RMS error: 1.056205
# (Iteration 1221 / 1830) loss: 0.858201
# (Iteration 1231 / 1830) loss: 0.593610
# (Iteration 1241 / 1830) loss: 0.705136
# (Iteration 1251 / 1830) loss: 0.885213
# (Iteration 1261 / 1830) loss: 0.686738
# (Iteration 1271 / 1830) loss: 0.782181
# (Iteration 1281 / 1830) loss: 0.720339
# (Iteration 1291 / 1830) loss: 0.697965
# (Iteration 1301 / 1830) loss: 0.699726
# (Iteration 1311 / 1830) loss: 0.794931
# (Iteration 1321 / 1830) loss: 0.733247
# (Iteration 1331 / 1830) loss: 0.778391
# (Iteration 1341 / 1830) loss: 0.735752
# (Epoch 11 / 15) train RMS error: 0.892390; val RMS error: 1.063880
# (Iteration 1351 / 1830) loss: 0.790338
# (Iteration 1361 / 1830) loss: 0.687331
# (Iteration 1371 / 1830) loss: 0.818876
# (Iteration 1381 / 1830) loss: 0.675846
# (Iteration 1391 / 1830) loss: 0.705001
# (Iteration 1401 / 1830) loss: 0.742379
# (Iteration 1411 / 1830) loss: 0.837589
# (Iteration 1421 / 1830) loss: 0.696309
# (Iteration 1431 / 1830) loss: 0.796935
# (Iteration 1441 / 1830) loss: 0.715845
# (Iteration 1451 / 1830) loss: 0.770469
# (Iteration 1461 / 1830) loss: 0.753457
# (Epoch 12 / 15) train RMS error: 0.895742; val RMS error: 1.061088
# (Iteration 1471 / 1830) loss: 0.736573
# (Iteration 1481 / 1830) loss: 0.892670
# (Iteration 1491 / 1830) loss: 0.785688
# (Iteration 1501 / 1830) loss: 0.787428
# (Iteration 1511 / 1830) loss: 0.857936
# (Iteration 1521 / 1830) loss: 0.722489
# (Iteration 1531 / 1830) loss: 0.772269
# (Iteration 1541 / 1830) loss: 0.744418
# (Iteration 1551 / 1830) loss: 0.677145
# (Iteration 1561 / 1830) loss: 0.726264
# (Iteration 1571 / 1830) loss: 0.748664
# (Iteration 1581 / 1830) loss: 0.552692
# (Epoch 13 / 15) train RMS error: 0.895293; val RMS error: 1.056708
# (Iteration 1591 / 1830) loss: 0.731860
# (Iteration 1601 / 1830) loss: 0.641301
# (Iteration 1611 / 1830) loss: 0.856702
# (Iteration 1621 / 1830) loss: 0.764591
# (Iteration 1631 / 1830) loss: 0.783893
# (Iteration 1641 / 1830) loss: 0.747532
# (Iteration 1651 / 1830) loss: 0.810464
# (Iteration 1661 / 1830) loss: 0.673135
# (Iteration 1671 / 1830) loss: 0.635452
# (Iteration 1681 / 1830) loss: 0.725562
# (Iteration 1691 / 1830) loss: 0.772181
# (Iteration 1701 / 1830) loss: 0.764231
# (Epoch 14 / 15) train RMS error: 0.903464; val RMS error: 1.051720
# (Iteration 1711 / 1830) loss: 0.712573
# (Iteration 1721 / 1830) loss: 0.801540
# (Iteration 1731 / 1830) loss: 0.674857
# (Iteration 1741 / 1830) loss: 0.687104
# (Iteration 1751 / 1830) loss: 0.758259
# (Iteration 1761 / 1830) loss: 0.716750
# (Iteration 1771 / 1830) loss: 0.908771
# (Iteration 1781 / 1830) loss: 0.658188
# (Iteration 1791 / 1830) loss: 0.871164
# (Iteration 1801 / 1830) loss: 0.840266
# (Iteration 1811 / 1830) loss: 0.707248
# (Iteration 1821 / 1830) loss: 0.708809
# (Epoch 15 / 15) train RMS error: 0.830308; val RMS error: 1.042755
# Validation RMS Error = 1.0428
#
# Optimal Hyperparameters: {'hidden_dims': [24, 48], 'lr': 0.001}
# Lowest Validation RMS Error: 0.6208

# %% [markdown]
# # Visualization (5)
#
# Choose and apply several relevant visualization techniques to evaluate the performance and behavior of a regression model. For each chosen technique, provide:
#
# 1. A brief description of the method and its purpose.
# 2. A demonstration of the method. (plot it)
# 3. An explanation of the insights gained from the visualization, focusing on what it reveals about the model's effectiveness.

# %%
# Run this cell to visualize training loss and train / val RMS error


def visualize_training_results(solver, title_prefix=""):
    """
    TODO: Implement a function to visualize training loss and train/validation RMS error.

    Parameters:
        - solver: An object containing 'loss_history', 'train_acc_history', and 'val_acc_history'.
        - title_prefix: A string to prefix the titles (optional).

    Returns:
        None
    """
    # TODO: Set figure size
    None  # Replace with correct function to create figure
    plt.figure(figsize=(15, 10))

    # TODO: Plot training loss history
    None  # Replace with correct function to create subplot
    plt.subplot(2, 1, 1)
    None  # Replace with correct function to set title
    plt.title(f'{title_prefix}Training Loss')
    None  # Replace with correct function to plot loss history
    plt.plot(solver.loss_history, 'o', markersize=2, alpha=0.5)
    None  # Replace with correct function to set x-axis label
    plt.xlabel('Iteration')

    # TODO: Plot train and validation RMS error
    None  # Replace with correct function to create subplot
    plt.subplot(2, 1, 2)
    None  # Replace with correct function to set title
    plt.title(f'{title_prefix}Validation RMS Error')
    None  # Replace with correct function to plot training accuracy
    plt.plot(solver.train_acc_history, '-o', label='Train')
    None  # Replace with correct function to plot validation accuracy
    plt.plot(solver.val_acc_history, '-o', label='Val')
    None  # Replace with correct function to set x-axis label
    plt.xlabel('Epoch')
    None  # Replace with correct function to add legend
    plt.legend(loc = "lower right")

    # TODO: Show the final plot
    None  # Replace with correct function to display the plot
    plt.tight_layout()
    plt.show()
    
#TODO: visualize_training_results(california_housing_solver)
visualize_training_results(california_housing_solver)
